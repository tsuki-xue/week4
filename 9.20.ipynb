# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.1.1; however, version 24.0 is available.
# You should consider upgrading via the 'd:\Python\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as np

# %%
path1 = "D:/Microsoft VS Code/da/drinks.csv"

# %%
df= np.read_csv(path1)

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
df.head(10)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# ...

# %%
df.tail()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 188  Venezuela            333              100              3
# 189    Vietnam            111                2              1
# 190      Yemen              6                0              0
# 191     Zambia             32               19              4
# 192   Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF

# %%
df.loc[:,['beer_servings','spirit_servings','wine_servings']].corr()
# Out:
#                  beer_servings  spirit_servings  wine_servings
# beer_servings         1.000000         0.458819       0.527172
# spirit_servings       0.458819         1.000000       0.194797
# wine_servings         0.527172         0.194797       1.000000

# %%
# %pip install seaborn-i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Cannot unpack file C:\Users\LENOVO\AppData\Local\Temp\pip-unpack-rrc3s0x3\simple.html (downloaded from C:\Users\LENOVO\AppData\Local\Temp\pip-req-build-va1dewia, content-type: text/html); cannot detect archive format
# ERROR: Cannot determine archive format of C:\Users\LENOVO\AppData\Local\Temp\pip-req-build-va1dewia
# WARNING: You are using pip version 20.1.1; however, version 24.0 is available.
# You should consider upgrading via the 'd:\Python\python.exe -m pip install --upgrade pip' command.

# %%
import seaborn as sns

# %%
data = df.loc[:,['wine_servings','beer_servings','spirit_servings','total_litres_of_pure_alcohol']].corr()
sns.heatmap(data=data,annot=True)
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
gb=df.groupby('continent')

# %%
list(gb)
# Out:
# [('AF',
#                         country  beer_servings  spirit_servings  wine_servings  \
#   2                     Algeria             25                0             14
#   4                      Angola            217               57             45
#   18                      Benin             34                4             13
#   22                   Botswana            173               35             35
#   26               Burkina Faso             25                7              7
#   27                    Burundi             88                0              0
#   28              Cote d'Ivoire             37                1              7
#   29                 Cabo Verde            144               56             16
#   31                   Cameroon            147                1              4
#   33   Central African Republic             17                2              1
#   34                       Chad             15                1              1
# ...

# %%
df.plot(x='country',y='beer_servings')
# Out:
# <AxesSubplot:xlabel='country'>

# %%
df.sort_values(['beer_servings'], ascending =False)
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 117         Namibia            376                3              1
# 45   Czech Republic            361              170            134
# 62            Gabon            347               98             59
# 65          Germany            346              117            175
# 98        Lithuania            343              244             56
# ..              ...            ...              ...            ...
# 107      Mauritania              0                0              0
# 158         Somalia              0                0              0
# 111          Monaco              0                0              0
# 128        Pakistan              0                0              0
# 0       Afghanistan              0                0              0
#
#      total_litres_of_pure_alcohol continent
# 117                           6.8        AF
# 45                           11.8        EU
# ...

# %%
df[df['beer_servings'] != 0]
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 1              Albania             89              132             54
# 2              Algeria             25                0             14
# 3              Andorra            245              138            312
# 4               Angola            217               57             45
# 5    Antigua & Barbuda            102              128             45
# ..                 ...            ...              ...            ...
# 188          Venezuela            333              100              3
# 189            Vietnam            111                2              1
# 190              Yemen              6                0              0
# 191             Zambia             32               19              4
# 192           Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 1                             4.9        EU
# ...

# %%
filtered_df = df[df['beer_servings'] != 0]

# %%
filtered_df.sort_values(['beer_servings'], ascending =False)
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 117         Namibia            376                3              1
# 45   Czech Republic            361              170            134
# 62            Gabon            347               98             59
# 65          Germany            346              117            175
# 135          Poland            343              215             56
# ..              ...            ...              ...            ...
# 168      Tajikistan              2               15              0
# 171     Timor-Leste              1                1              4
# 137           Qatar              1               42              7
# 38          Comoros              1                3              1
# 73            Haiti              1              326              1
#
#      total_litres_of_pure_alcohol continent
# 117                           6.8        AF
# 45                           11.8        EU
# ...

# %%
line=filtered_df.sort_values(['beer_servings'], ascending =False)

# %%
df['country'].str[0:3]
# Out:
# 0      Afg
# 1      Alb
# 2      Alg
# 3      And
# 4      Ang
#       ...
# 188    Ven
# 189    Vie
# 190    Yem
# 191    Zam
# 192    Zim
# Name: country, Length: 193, dtype: object

# %%
line.plot(x='country',y='beer_servings')
# Out:
# <AxesSubplot:xlabel='country'>
